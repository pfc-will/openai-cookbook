# %%
import requests
import re
import urllib.request
from bs4 import BeautifulSoup
from collections import deque
from html.parser import HTMLParser
from urllib.parse import urlparse
import os

# Regex pattern to match a URL
HTTP_URL_PATTERN = r'^http[s]*://.+'

# Define root domain to crawl
domain = "developers.arcgis.com"
full_url = "https://developers.arcgis.com/rest/users-groups-and-items/working-with-users-groups-and-items.htm"

# Create a class to parse the HTML and get the hyperlinks
class HyperlinkParser(HTMLParser):
    def __init__(self, target_div_id):
        super().__init__()
        self.target_div_id = target_div_id
        self.is_target_div = False
        # Create a list to store the hyperlinks
        self.hyperlinks = []
        self.target_div_flag = 0

    # Override the HTMLParser's handle_starttag method to get the hyperlinks
    def handle_starttag(self, tag, attrs):
        "".find
        

        if tag == 'div':
            for attr in attrs:
                if attr[0] == 'class' and 'trailer-2' in attr[1]:
                    self.is_target_div = True
                    break

        if tag == 'div' and self.is_target_div:
            self.target_div_flag += 1

        if not self.is_target_div:
            return
        attrs = dict(attrs)
        # If the tag is an anchor tag and it has an href attribute, add the href attribute to the list of hyperlinks
        if self.is_target_div and tag == "a" and "href" in attrs:
            self.hyperlinks.append(attrs["href"])

    def handle_endtag(self, tag):
        if tag == 'div' and self.is_target_div:
            self.target_div_flag -= 1
            if self.target_div_flag == 0:
                self.is_target_div = False

# Function to get the hyperlinks from a URL
def get_hyperlinks(url):
    
    # Try to open the URL and read the HTML
    try:
        # Open the URL and read the HTML
        with urllib.request.urlopen(url) as response:

            # If the response is not HTML, return an empty list
            if not response.info().get('Content-Type').startswith("text/html"):
                return []
            
            # Decode the HTML
            html = response.read().decode('utf-8')
    except Exception as e:
        print(e)
        return []

    # Create the HTML Parser and then Parse the HTML to get hyperlinks
    parser = HyperlinkParser('skip-to-content')
    parser.feed(html)

    return parser.hyperlinks

# Function to get the hyperlinks from a URL that are within the same domain
def get_domain_hyperlinks(local_domain, url):
    clean_links = []
    for link in set(get_hyperlinks(url)):
        clean_link = None

        # If the link is a URL, check if it is within the same domain
        if re.search(HTTP_URL_PATTERN, link):
            # Parse the URL and check if the domain is the same
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain:
                clean_link = link

        # If the link is not a URL, check if it is a relative link
        else:
            if link.startswith("/"):
                link = link[1:]
            elif link.startswith("#") or link.startswith("mailto:"):
                continue
            clean_link = "https://" + local_domain + "/" + link

        if clean_link is not None:
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            clean_links.append(clean_link)

    # Return the list of hyperlinks that are within the same domain
    return list(set(clean_links))


def crawl(url):
    # Parse the URL and get the domain
    local_domain = urlparse(url).netloc

    # Create a queue to store the URLs to crawl
    queue = deque([url])

    # Create a set to store the URLs that have already been seen (no duplicates)
    seen = set([url])

    # Create a directory to store the text files
    if not os.path.exists("text/"):
            os.mkdir("text/")

    if not os.path.exists("text/"+local_domain+"/"):
            os.mkdir("text/" + local_domain + "/")

    # Create a directory to store the csv files
    if not os.path.exists("processed"):
            os.mkdir("processed")

    # While the queue is not empty, continue crawling
    while queue:

        # Get the next URL from the queue
        url = queue.pop()
        print(url) # for debugging and to see the progress

        # Save text from the url to a <url>.txt file
        with open('text/'+local_domain+'/'+url[8:].replace("/", "_") + ".txt", "w") as f:

            # Get the text from the URL using BeautifulSoup
            soup = BeautifulSoup(requests.get(url).text, "html.parser")

            # Get the text but remove the tags
            text = soup.get_text()

            # If the crawler gets to a page that requires JavaScript, it will stop the crawl
            if ("You need to enable JavaScript to run this app." in text):
                print("Unable to parse page " + url + " due to JavaScript being required")
            
            # Otherwise, write the text to the file in the text directory
            f.write(text)

        # Get the hyperlinks from the URL and add them to the queue
        for link in get_domain_hyperlinks(local_domain, url):
            if link not in seen:
                queue.append(link)
                seen.add(link)

crawl(full_url)
# Out:
# https://developers.arcgis.com/rest/users-groups-and-items/working-with-users-groups-and-items.htm
# https://developers.arcgis.com/rest/users-groups-and-items/item-rating.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-entitlements-username-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-info.htm
# https://developers.arcgis.com/rest/users-groups-and-items/set-content-status.htm
# https://developers.arcgis.com/rest/users-groups-and-items/move-items.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-app-bundles.htm
# https://developers.arcgis.com/rest/users-groups-and-items/invalidate-collaboration-invitation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/protect-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-provision.htm
# https://developers.arcgis.com/rest/users-groups-and-items/export-group-content.htm
# https://developers.arcgis.com/rest/users-groups-and-items/collaborations.htm
# https://developers.arcgis.com/rest/users-groups-and-items/all-user-scheduled-tasks.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-relationship.htm
# https://developers.arcgis.com/rest/users-groups-and-items/reassign-items.htm
# https://developers.arcgis.com/rest/users-groups-and-items/member-category-schema.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-invitation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-thumbnail.htm
# https://developers.arcgis.com/rest/users-groups-and-items/assign-member-category-schema.htm
# https://developers.arcgis.com/rest/users-groups-and-items/regions.htm
# https://developers.arcgis.com/rest/users-groups-and-items/item-data.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-webhook.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-comment.htm
# https://developers.arcgis.com/rest/users-groups-and-items/collaboration-workspaces.htm
# https://developers.arcgis.com/rest/users-groups-and-items/register-app.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/list-specific-webhook.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unlist-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/listing.htm
# https://developers.arcgis.com/rest/users-groups-and-items/commit.htm
# https://developers.arcgis.com/rest/users-groups-and-items/self.htm
# https://developers.arcgis.com/rest/users-groups-and-items/describe-datastore.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-task.htm
# https://developers.arcgis.com/rest/users-groups-and-items/notification.htm
# https://developers.arcgis.com/rest/users-groups-and-items/sync-status.htm
# https://developers.arcgis.com/rest/users-groups-and-items/authentication.htm
# https://developers.arcgis.com/rest/users-groups-and-items/express-interest.htm
# https://developers.arcgis.com/rest/users-groups-and-items/server.htm
# https://developers.arcgis.com/rest/users-groups-and-items/content-root.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unassign-user-credits.htm
# https://developers.arcgis.com/rest/users-groups-and-items/can-delete-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/activate-webhook.htm
# https://developers.arcgis.com/rest/users-groups-and-items/collaboration.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-security-policy.htm
# https://developers.arcgis.com/rest/users-groups-and-items/revoke-token.htm
# https://developers.arcgis.com/rest/users-groups-and-items/collaboration-participant.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-portal-group-link.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-layers.htm
# https://developers.arcgis.com/rest/users-groups-and-items/item-resource.htm
# https://developers.arcgis.com/rest/users-groups-and-items/organization-settings.htm
# https://developers.arcgis.com/rest/users-groups-and-items/copy-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/roles.htm
# https://developers.arcgis.com/rest/users-groups-and-items/remove-users-from-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/item-comment.htm
# https://developers.arcgis.com/rest/users-groups-and-items/register-idp.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-user.htm
# https://developers.arcgis.com/rest/users-groups-and-items/root.htm
# https://developers.arcgis.com/rest/users-groups-and-items/set-user-default-settings.htm
# https://developers.arcgis.com/rest/users-groups-and-items/collaboration-workspace.htm
# https://developers.arcgis.com/rest/users-groups-and-items/remove-resources.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-item-delete-policy.htm
# https://developers.arcgis.com/rest/users-groups-and-items/proxies.htm
# https://developers.arcgis.com/rest/users-groups-and-items/users.htm
# https://developers.arcgis.com/rest/users-groups-and-items/create-new-scheduled-task.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-run.htm
# https://developers.arcgis.com/rest/users-groups-and-items/generate-token.htm
# https://developers.arcgis.com/rest/users-groups-and-items/item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/protect.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unregister-certificate.htm
# https://developers.arcgis.com/rest/users-groups-and-items/create-service-image-service-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/refresh-collaboration-invitation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/item-resources.htm
# https://developers.arcgis.com/rest/users-groups-and-items/webhooks.htm
# https://developers.arcgis.com/rest/users-groups-and-items/remove-resource.htm
# https://developers.arcgis.com/rest/users-groups-and-items/marketplace-overview.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-collaboration-info.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unshare-item-as-item-owner-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/import-collaboration-invitation-response.htm
# https://developers.arcgis.com/rest/users-groups-and-items/reports.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-relationship.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-role.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-member-category-schema.htm
# https://developers.arcgis.com/rest/users-groups-and-items/registered-app-info.htm
# https://developers.arcgis.com/rest/users-groups-and-items/related-items.htm
# https://developers.arcgis.com/rest/users-groups-and-items/reassign-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/resource-hierarchy.htm
# https://developers.arcgis.com/rest/users-groups-and-items/group-content-search.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-comment.htm
# https://developers.arcgis.com/rest/users-groups-and-items/register-federation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/create-webhooks.htm
# https://developers.arcgis.com/rest/users-groups-and-items/analyze.htm
# https://developers.arcgis.com/rest/users-groups-and-items/create-service.htm
# https://developers.arcgis.com/rest/users-groups-and-items/metadata-reference.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-idp.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-resource.htm
# https://developers.arcgis.com/rest/users-groups-and-items/idp.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-default-settings.htm
# https://developers.arcgis.com/rest/users-groups-and-items/publish-layers.htm
# https://developers.arcgis.com/rest/users-groups-and-items/publish-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-search-org-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/remove-users-portal-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-invitations.htm
# https://developers.arcgis.com/rest/users-groups-and-items/export-item-resources.htm
# https://developers.arcgis.com/rest/users-groups-and-items/remove-from-server.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unshare-items.htm
# https://developers.arcgis.com/rest/users-groups-and-items/export-user-item-resources.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-server.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-to-server.htm
# https://developers.arcgis.com/rest/users-groups-and-items/category-schema.htm
# https://developers.arcgis.com/rest/users-groups-and-items/register-server.htm
# https://developers.arcgis.com/rest/users-groups-and-items/deactivate-webhook.htm
# https://developers.arcgis.com/rest/users-groups-and-items/generate.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-settings.htm
# https://developers.arcgis.com/rest/users-groups-and-items/replace-service.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-search.htm
# https://developers.arcgis.com/rest/users-groups-and-items/disable-task.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-group-thumbnail.htm
# https://developers.arcgis.com/rest/users-groups-and-items/group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/collaboration-participants.htm
# https://developers.arcgis.com/rest/users-groups-and-items/start-trial.htm
# https://developers.arcgis.com/rest/users-groups-and-items/decline-invitation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/import-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/oauth2-root.htm
# https://developers.arcgis.com/rest/users-groups-and-items/configure-social-providers.htm
# https://developers.arcgis.com/rest/users-groups-and-items/feature-content-root.htm
# https://developers.arcgis.com/rest/users-groups-and-items/accept-invitation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/decline-group-application.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user.htm
# https://developers.arcgis.com/rest/users-groups-and-items/create-folder.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-info.htm
# https://developers.arcgis.com/rest/users-groups-and-items/can-reassign-items.htm
# https://developers.arcgis.com/rest/users-groups-and-items/provisioned-listings.htm
# https://developers.arcgis.com/rest/users-groups-and-items/group-application.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-participant-info.htm
# https://developers.arcgis.com/rest/users-groups-and-items/register-certificate.htm
# https://developers.arcgis.com/rest/users-groups-and-items/accept-group-application.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-collaboration-workspace.htm
# https://developers.arcgis.com/rest/users-groups-and-items/reassign-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/sync-status-details.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-content.htm
# https://developers.arcgis.com/rest/users-groups-and-items/suggest.htm
# https://developers.arcgis.com/rest/users-groups-and-items/relationship-types.htm
# https://developers.arcgis.com/rest/users-groups-and-items/list-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/listings-search.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-service-proxy-configuration.htm
# https://developers.arcgis.com/rest/users-groups-and-items/can-reassign-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/create-role.htm
# https://developers.arcgis.com/rest/users-groups-and-items/share-item-as-item-owner-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/item-comments.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-webhook.htm
# https://developers.arcgis.com/rest/users-groups-and-items/invite-collaboration-participant.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-tags.htm
# https://developers.arcgis.com/rest/users-groups-and-items/group-search.htm
# https://developers.arcgis.com/rest/users-groups-and-items/cancel.htm
# https://developers.arcgis.com/rest/users-groups-and-items/role.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-rating.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/purchase-listing.htm
# https://developers.arcgis.com/rest/users-groups-and-items/search.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-collaboration.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-entitlements.htm
# https://developers.arcgis.com/rest/users-groups-and-items/package-info-file.htm
# https://developers.arcgis.com/rest/users-groups-and-items/create-collaboration.htm
# https://developers.arcgis.com/rest/users-groups-and-items/authorize.htm
# https://developers.arcgis.com/rest/users-groups-and-items/leave-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/servers.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-participant-access-mode.htm
# https://developers.arcgis.com/rest/users-groups-and-items/create-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-user-thumbnail.htm
# https://developers.arcgis.com/rest/users-groups-and-items/certificates.htm
# https://developers.arcgis.com/rest/users-groups-and-items/export-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/validate-collaboration-invitation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/provision-user-entitlements.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-group-items-with-content-categories.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-license-types.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-certificate.htm
# https://developers.arcgis.com/rest/users-groups-and-items/remove-user-resource.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-item-link-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-item-resource.htm
# https://developers.arcgis.com/rest/users-groups-and-items/federation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/notifications.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-collaboration-workspace.htm
# https://developers.arcgis.com/rest/users-groups-and-items/all-scheduled-tasks.htm
# https://developers.arcgis.com/rest/users-groups-and-items/all-datasets.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-resources.htm
# https://developers.arcgis.com/rest/users-groups-and-items/resources-portal-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-user-role.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-user-level.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-proxy.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unprotect.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-user.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unshare-item-as-group-admin-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/collaboration-invitations.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unprotect-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/items-and-item-types.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-items-with-content-categories.htm
# https://developers.arcgis.com/rest/users-groups-and-items/validate-datastore.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-role.htm
# https://developers.arcgis.com/rest/users-groups-and-items/customers-list.htm
# https://developers.arcgis.com/rest/users-groups-and-items/accept-collaboration-invitation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/get-specific-task.htm
# https://developers.arcgis.com/rest/users-groups-and-items/remove-participant.htm
# https://developers.arcgis.com/rest/users-groups-and-items/share-items.htm
# https://developers.arcgis.com/rest/users-groups-and-items/assign-user-credits.htm
# https://developers.arcgis.com/rest/users-groups-and-items/share-item-as-group-admin-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-schedule.htm
# https://developers.arcgis.com/rest/users-groups-and-items/group-users-list.htm
# https://developers.arcgis.com/rest/users-groups-and-items/runs-for-task.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-item-part.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-organization-settings.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-rating.htm
# https://developers.arcgis.com/rest/users-groups-and-items/pause.htm
# https://developers.arcgis.com/rest/users-groups-and-items/languages.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-federation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/create-service-relational-catalog-service-.htm
# https://developers.arcgis.com/rest/users-groups-and-items/resume.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/notification-status.htm
# https://developers.arcgis.com/rest/users-groups-and-items/purchases.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unregister-server.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-folder.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-users-to-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-proxy.htm
# https://developers.arcgis.com/rest/users-groups-and-items/invite-to-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-group-category-schema.htm
# https://developers.arcgis.com/rest/users-groups-and-items/remove-portal-group-link.htm
# https://developers.arcgis.com/rest/users-groups-and-items/token.htm
# https://developers.arcgis.com/rest/users-groups-and-items/item-info-file.htm
# https://developers.arcgis.com/rest/users-groups-and-items/set-role-privileges.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-collaboration-workspace.htm
# https://developers.arcgis.com/rest/users-groups-and-items/assign-group-category-schema.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-web-tier-authentication-configuration.htm
# https://developers.arcgis.com/rest/users-groups-and-items/group-users.htm
# https://developers.arcgis.com/rest/users-groups-and-items/search-reference.htm
# https://developers.arcgis.com/rest/users-groups-and-items/portals-root.htm
# https://developers.arcgis.com/rest/users-groups-and-items/edit-existing-task.htm
# https://developers.arcgis.com/rest/users-groups-and-items/considerations-and-limitations.htm
# https://developers.arcgis.com/rest/users-groups-and-items/portal-self.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unregister-federation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/common-parameters.htm
# https://developers.arcgis.com/rest/users-groups-and-items/group-applications.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-resources.htm
# https://developers.arcgis.com/rest/users-groups-and-items/conceptual-hierarchy.htm
# https://developers.arcgis.com/rest/users-groups-and-items/community-root.htm
# https://developers.arcgis.com/rest/users-groups-and-items/validate-collaboration-invitation-response.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unregister-app.htm
# https://developers.arcgis.com/rest/users-groups-and-items/certificate.htm
# https://developers.arcgis.com/rest/users-groups-and-items/export-collaboration-invitation-response.htm
# https://developers.arcgis.com/rest/users-groups-and-items/enable.htm
# https://developers.arcgis.com/rest/users-groups-and-items/collaboration-invitation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/schedule.htm
# https://developers.arcgis.com/rest/users-groups-and-items/get-layers.htm
# https://developers.arcgis.com/rest/users-groups-and-items/disable.htm
# https://developers.arcgis.com/rest/users-groups-and-items/social-providers.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-proxies.htm
# https://developers.arcgis.com/rest/users-groups-and-items/refresh-server.htm
# https://developers.arcgis.com/rest/users-groups-and-items/registered-app.htm
# https://developers.arcgis.com/rest/users-groups-and-items/what-s-new-in-users-groups-and-items.htm
# https://developers.arcgis.com/rest/users-groups-and-items/group-content.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-schedule.htm
# https://developers.arcgis.com/rest/users-groups-and-items/edit-run.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-folder.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/groups.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-notification.htm
# https://developers.arcgis.com/rest/users-groups-and-items/parts.htm
# https://developers.arcgis.com/rest/users-groups-and-items/status.htm
# https://developers.arcgis.com/rest/users-groups-and-items/add-user-resource.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-category-schema.htm
# https://developers.arcgis.com/rest/users-groups-and-items/check-service-name.htm
# https://developers.arcgis.com/rest/users-groups-and-items/portal.htm
# https://developers.arcgis.com/rest/users-groups-and-items/enable-task.htm
# https://developers.arcgis.com/rest/users-groups-and-items/remove-social-providers.htm
# https://developers.arcgis.com/rest/users-groups-and-items/group-category-schema.htm
# https://developers.arcgis.com/rest/users-groups-and-items/create-proxies.htm
# https://developers.arcgis.com/rest/users-groups-and-items/sync.htm
# https://developers.arcgis.com/rest/users-groups-and-items/privileges.htm
# https://developers.arcgis.com/rest/users-groups-and-items/remove-collaboration-participation.htm
# https://developers.arcgis.com/rest/users-groups-and-items/proxy.htm
# https://developers.arcgis.com/rest/users-groups-and-items/assign-category-schema.htm
# https://developers.arcgis.com/rest/users-groups-and-items/provision-organization-entitlements.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-items.htm
# https://developers.arcgis.com/rest/users-groups-and-items/user-item-resources.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-comment.htm
# https://developers.arcgis.com/rest/users-groups-and-items/publish-datasets-to-datastore.htm
# https://developers.arcgis.com/rest/users-groups-and-items/move-item.htm
# https://developers.arcgis.com/rest/users-groups-and-items/join-group.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-user-default-settings.htm
# https://developers.arcgis.com/rest/users-groups-and-items/portal-history.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update-service-proxy-configuration.htm
# https://developers.arcgis.com/rest/users-groups-and-items/get-servers-for-data-store.htm
# https://developers.arcgis.com/rest/users-groups-and-items/delete-item-thumbnail.htm
# https://developers.arcgis.com/rest/users-groups-and-items/security-policy.htm
# https://developers.arcgis.com/rest/users-groups-and-items/settings.htm
# https://developers.arcgis.com/rest/users-groups-and-items/unregister-idp.htm
# https://developers.arcgis.com/rest/users-groups-and-items/update.htm
# https://developers.arcgis.com/rest/users-groups-and-items/datastore.htm

# %%
def remove_newlines(serie):
    serie = serie.str.replace('\n', ' ')
    serie = serie.str.replace('\\n', ' ')
    serie = serie.str.replace('  ', ' ')
    serie = serie.str.replace('  ', ' ')
    return serie

# %%
import pandas as pd

# Create a list to store the text files
texts=[]

# Get all the text files in the text directory
for file in os.listdir("text/" + domain + "/"):

    # Open the file and read the text
    with open("text/" + domain + "/" + file, "r") as f:
        text = f.read()

        # Omit the first 11 lines and the last 4 lines, then replace -, _, and #update with spaces.
        texts.append((file[11:-4].replace('-',' ').replace('_', ' ').replace('#update',''), text))

# Create a dataframe from the list of texts
df = pd.DataFrame(texts, columns = ['fname', 'text'])

# Set the text column to be the raw text with the newlines removed
df['text'] = df.fname + ". " + remove_newlines(df.text)
df.to_csv('processed/scraped.csv')
df.head()
# Out:
# /var/folders/d5/6pd8rxrj7dvfsvtwm7mdbtwc0000gn/T/ipykernel_96394/2931785837.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   serie = serie.str.replace('\\n', ' ')
#                                                fname  \
# 0  arcgis.com rest users groups and items update ...
# 1  arcgis.com rest users groups and items update ...
# 2  arcgis.com rest users groups and items group u...
# 3  arcgis.com rest users groups and items analyze...
# 4  arcgis.com rest users groups and items user en...
#
#                                                 text
# 0  arcgis.com rest users groups and items update ...
# 1  arcgis.com rest users groups and items update ...
# 2  arcgis.com rest users groups and items group u...
# 3  arcgis.com rest users groups and items analyze...
# 4  arcgis.com rest users groups and items user en...

# %%
import tiktoken

# Load the cl100k_base tokenizer which is designed to work with the ada-002 model
tokenizer = tiktoken.get_encoding("cl100k_base")

df = pd.read_csv('processed/scraped.csv', index_col=0)
df.columns = ['title', 'text']

# Tokenize the text and save the number of tokens to a new column
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))

# Visualize the distribution of the number of tokens per row using a histogram
df.n_tokens.hist()
# Out:
# <AxesSubplot: >

# %%
max_tokens = 500

# Function to split the text into chunks of a maximum number of tokens
def split_into_many(text, max_tokens = max_tokens):

    # Split the text into sentences
    sentences = text.split('. ')

    # Get the number of tokens for each sentence
    n_tokens = [len(tokenizer.encode(" " + sentence)) for sentence in sentences]
    
    chunks = []
    tokens_so_far = 0
    chunk = []

    # Loop through the sentences and tokens joined together in a tuple
    for sentence, token in zip(sentences, n_tokens):

        # If the number of tokens so far plus the number of tokens in the current sentence is greater 
        # than the max number of tokens, then add the chunk to the list of chunks and reset
        # the chunk and tokens so far
        if tokens_so_far + token > max_tokens:
            chunks.append(". ".join(chunk) + ".")
            chunk = []
            tokens_so_far = 0

        # If the number of tokens in the current sentence is greater than the max number of 
        # tokens, go to the next sentence
        if token > max_tokens:
            continue

        # Otherwise, add the sentence to the chunk and add the number of tokens to the total
        chunk.append(sentence)
        tokens_so_far += token + 1

    return chunks
    

shortened = []

# Loop through the dataframe
for row in df.iterrows():

    # If the text is None, go to the next row
    if row[1]['text'] is None:
        continue

    # If the number of tokens is greater than the max number of tokens, split the text into chunks
    if row[1]['n_tokens'] > max_tokens:
        shortened += split_into_many(row[1]['text'])
    
    # Otherwise, add the text to the list of shortened texts
    else:
        shortened.append( row[1]['text'] )

# %%
df = pd.DataFrame(shortened, columns = ['text'])
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))
df.n_tokens.hist()
# Out:
# <AxesSubplot: >

# %%
df
# Out:
#                                                   text  n_tokens
# 0    arcgis.com rest users groups and items update ...        12
# 1                                                    .         1
# 2    arcgis.com rest users groups and items update ...        14
# 3    arcgis.com rest users groups and items group u...        12
# 4    arcgis.com rest users groups and items analyze...        11
# ..                                                 ...       ...
# 630  arcgis.com rest users groups and items invite ...        13
# 631  The inviteParticipant operation allows you to ...       305
# 632  arcgis.com rest users groups and items delete ...        12
# 633  arcgis.com rest users groups and items set con...        13
# 634  To change an item's status to either authorita...       427
#
# [635 rows x 2 columns]

# %%
import openai

df['embeddings'] = df.text.apply(lambda x: openai.Embedding.create(input=x, engine='text-embedding-ada-002')['data'][0]['embedding'])
df.to_csv('processed/embeddings.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[7], line 3
#       1 import openai
# ----> 3 df['embeddings'] = df.text.apply(lambda x: openai.Embedding.create(input=x, engine='text-embedding-ada-002')['data'][0]['embedding'])
#       4 df.to_csv('processed/embeddings.csv')
#       5 df.head()
#
# File ~/Documents/my/openai-cookbook/env/lib/python3.8/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/Documents/my/openai-cookbook/env/lib/python3.8/site-packages/pandas/core/apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File ~/Documents/my/openai-cookbook/env/lib/python3.8/site-packages/pandas/core/apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Documents/my/openai-cookbook/env/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# Cell In[7], line 3, in <lambda>(x)
#       1 import openai
# ----> 3 df['embeddings'] = df.text.apply(lambda x: openai.Embedding.create(input=x, engine='text-embedding-ada-002')['data'][0]['embedding'])
#       4 df.to_csv('processed/embeddings.csv')
#       5 df.head()
#
# File ~/Documents/my/openai-cookbook/env/lib/python3.8/site-packages/openai/api_resources/embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      31 while True:
#      32     try:
# ---> 33         response = super().create(*args, **kwargs)
#      35         # If a user specifies base64, we'll just return the encoded string.
#      36         # This is only for the default case.
#      37         if not user_provided_encoding_format:
#
# File ~/Documents/my/openai-cookbook/env/lib/python3.8/site-packages/openai/api_resources/abstract/engine_api_resource.py:149, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#     141         timeout,
#     142         stream,
#     143         headers,
#     144         request_timeout,
#     145         typed_api_type,
#     146         requestor,
#     147         url,
#     148         params,
# --> 149     ) = cls.__prepare_create_request(
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
#     153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#    (...)
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#
# File ~/Documents/my/openai-cookbook/env/lib/python3.8/site-packages/openai/api_resources/abstract/engine_api_resource.py:106, in EngineAPIResource.__prepare_create_request(cls, api_key, api_base, api_type, api_version, organization, **params)
#     103 elif timeout == 0:
#     104     params["timeout"] = MAX_TIMEOUT
# --> 106 requestor = api_requestor.APIRequestor(
#     107     api_key,
#     108     api_base=api_base,
#     109     api_type=api_type,
#     110     api_version=api_version,
#     111     organization=organization,
#     112 )
#     113 url = cls.class_url(engine, api_type, api_version)
#     114 return (
#     115     deployment_id,
#     116     engine,
#    (...)
#     124     params,
#     125 )
#
# File ~/Documents/my/openai-cookbook/env/lib/python3.8/site-packages/openai/api_requestor.py:131, in APIRequestor.__init__(self, key, api_base, api_type, api_version, organization)
#     122 def __init__(
#     123     self,
#     124     key=None,
#    (...)
#     128     organization=None,
#     129 ):
#     130     self.api_base = api_base or openai.api_base
# --> 131     self.api_key = key or util.default_api_key()
#     132     self.api_type = (
#     133         ApiType.from_str(api_type)
#     134         if api_type
#     135         else ApiType.from_str(openai.api_type)
#     136     )
#     137     self.api_version = api_version or openai.api_version
#
# File ~/Documents/my/openai-cookbook/env/lib/python3.8/site-packages/openai/util.py:186, in default_api_key()
#     184     return openai.api_key
#     185 else:
# --> 186     raise openai.error.AuthenticationError(
#     187         "No API key provided. You can set your API key in code using 'openai.api_key = <API-KEY>', or you can set the environment variable OPENAI_API_KEY=<API-KEY>). If your API key is stored in a file, you can point the openai module at it with 'openai.api_key_path = <PATH>'. You can generate API keys in the OpenAI web interface. See https://onboard.openai.com for details, or email support@openai.com if you have any questions."
#     188     )
#
# AuthenticationError: No API key provided. You can set your API key in code using 'openai.api_key = <API-KEY>', or you can set the environment variable OPENAI_API_KEY=<API-KEY>). If your API key is stored in a file, you can point the openai module at it with 'openai.api_key_path = <PATH>'. You can generate API keys in the OpenAI web interface. See https://onboard.openai.com for details, or email support@openai.com if you have any questions.

# %%
from openai.embeddings_utils import distances_from_embeddings

df['embeddings'] = df.text.apply(lambda x: openai.Embedding.create(input=x, engine='text-embedding-ada-002')['data'][0]['embedding'])

df.to_csv('processed/embeddings.csv')
df.head()
# Out:
#                                                 text  n_tokens  \
# 0  blog authors maddie.   Maddie Hall - OpenAI   ...       175
# 1  blog authors tom.   Tom Brown - OpenAI        ...       228
# 2  blog openai scholars 2019 final projects.   Op...       492
# 3  In this project, I used curiosity-driven explo...       478
# 4  Results revealed that the optimal RL policies ...       499
#
#                                           embeddings
# 0  [-0.012958061881363392, -0.006103983614593744,...
# 1  [-0.0053874170407652855, -0.009962032549083233...
# 2  [0.0019150723237544298, -0.0070442273281514645...
# 3  [-0.0067560747265815735, 0.0004431474662851542...
# 4  [-0.012868616729974747, 0.0029640409629791975,...

# %%
import pandas as pd
import numpy as np
from openai.embeddings_utils import distances_from_embeddings, cosine_similarity

df=pd.read_csv('processed/embeddings.csv', index_col=0)
df['embeddings'] = df['embeddings'].apply(eval).apply(np.array)

df.head()
# Out:
#                                                 text  n_tokens  \
# 0  blog authors maddie.   Maddie Hall - OpenAI   ...       175
# 1  blog authors tom.   Tom Brown - OpenAI        ...       228
# 2  blog openai scholars 2019 final projects.   Op...       492
# 3  In this project, I used curiosity-driven explo...       478
# 4  Results revealed that the optimal RL policies ...       499
#
#                                           embeddings
# 0  [-0.012958061881363392, -0.006103983614593744,...
# 1  [-0.0053874170407652855, -0.009962032549083233...
# 2  [0.0019150723237544298, -0.0070442273281514645...
# 3  [-0.0067560747265815735, 0.0004431474662851542...
# 4  [-0.012868616729974747, 0.0029640409629791975,...

# %%
def create_context(
    question, df, max_len=1800, size="ada"
):
    """
    Create a context for a question by finding the most similar context from the dataframe
    """

    # Get the embeddings for the question
    q_embeddings = openai.Embedding.create(input=question, engine='text-embedding-ada-002')['data'][0]['embedding']

    # Get the distances from the embeddings
    df['distances'] = distances_from_embeddings(q_embeddings, df['embeddings'].values, distance_metric='cosine')


    returns = []
    cur_len = 0

    # Sort by distance and add the text to the context until the context is too long
    for i, row in df.sort_values('distances', ascending=True).iterrows():
        
        # Add the length of the text to the current length
        cur_len += row['n_tokens'] + 4
        
        # If the context is too long, break
        if cur_len > max_len:
            break
        
        # Else add it to the text that is being returned
        returns.append(row["text"])

    # Return the context
    return "\n\n###\n\n".join(returns)

def answer_question(
    df,
    model="text-davinci-003",
    question="Am I allowed to publish model outputs to Twitter, without a human review?",
    max_len=1800,
    size="ada",
    debug=False,
    max_tokens=150,
    stop_sequence=None
):
    """
    Answer a question based on the most similar context from the dataframe texts
    """
    context = create_context(
        question,
        df,
        max_len=max_len,
        size=size,
    )
    # If debug, print the raw model response
    if debug:
        print("Context:\n" + context)
        print("\n\n")

    try:
        # Create a completions using the question and context
        response = openai.Completion.create(
            prompt=f"Answer the question based on the context below, and if the question can't be answered based on the context, say \"I don't know\"\n\nContext: {context}\n\n---\n\nQuestion: {question}\nAnswer:",
            temperature=0,
            max_tokens=max_tokens,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
            stop=stop_sequence,
            model=model,
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(e)
        return ""
# Out:
# 'No, you are not allowed to publish model outputs to Twitter without a human review. You must manually review each generation before sharing or while streaming, and indicate that the content is AI-generated in a way no user could reasonably miss or misunderstand.'

# %%
answer_question(df, question="What day is it?", debug=False)
# Out:
# "I don't know."

# %%
answer_question(df, question="What is our newest embeddings model?")
# Out:
# 'The newest embeddings model is text-embedding-ada-002.'
